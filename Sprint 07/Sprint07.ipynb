# %% [markdown]
# Nivell 1
# Exercici 1
# Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades. Pots obtenir més informació del seu càlcul en:
#
# La funció ha de classificar el resultat en les seves respectives categories

# %%
def pedir_datos():
    peso = float(input('Cuánto pesas en kilos (usa punto si hay decimales): '))
    altura = float(input('Cuánto mides en metros (usa punto si hay decimales): '))
    return peso, altura

def calcular_imc(peso, altura):
    return peso / altura ** 2

def mostrar_resultado(imc):
    imc_redondeado = round(imc, 2)
    if imc < 18.5:
        print(f"Tu IMC es: {imc_redondeado}, lo que se considera Bajo Peso (menos de 18,5)")
    elif imc < 25:
        print(f"Tu IMC es: {imc_redondeado}, lo que se considera Peso Normal (entre 18,5 y 24,9)")
    elif imc < 30:
        print(f"Tu IMC es: {imc_redondeado}, lo que se considera Sobrepeso (entre 25 y 29,9)")
    else:
        print(f"Tu IMC es: {imc_redondeado}, lo que se considera Obesidad (más de 30)")

def contesta_imc():
    peso, altura = pedir_datos()
    imc = calcular_imc(peso, altura)
    mostrar_resultado(imc)

contesta_imc()
# Out:
# Tu IMC es: 16.62, lo que se considera Bajo Peso (menos de 18,5)

# %% [markdown]
# Nivell 1
# Exercici 2
# Convertidor de temperatures.
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re). Selecciona almenys 2 conversors, de tal manera que en introduir una (cualquiera) temperatura retorni, com a mínim, dues conversions.

# %%
diccionario_conversiones = {
    # Celsius a otras
    'ctof': lambda c: c * 9/5 + 32, #lambda és una funcion sin nombre, de una sola linea. argumento y expresion adelante.
    'ctok': lambda c: c + 273.15,
    'ctor': lambda c: (c + 273.15) * 9/5,
    'ctore': lambda c: c * 4/5,

    # Fahrenheit a otras
    'ftoc': lambda f: (f - 32) * 5/9,
    'ftok': lambda f: (f - 32) * 5/9 + 273.15,
    'ftor': lambda f: f + 459.67,
    'ftore': lambda f: (f - 32) * 4/9,

    # Kelvin a otras
    'ktoc': lambda k: k - 273.15,
    'ktof': lambda k: (k - 273.15) * 9/5 + 32,
    'ktor': lambda k: k * 9/5,
    'ktore': lambda k: (k - 273.15) * 4/5,

    # Rankine a otras
    'rtoc': lambda r: (r - 491.67) * 5/9,
    'rtof': lambda r: r - 459.67,
    'rtok': lambda r: r * 5/9,
    'rtore': lambda r: ((r - 491.67) * 5/9) * 4/5,

    # Réaumur a otras
    'rectoc': lambda re: re * 5/4,
    'rectof': lambda re: re * 9/4 + 32,
    'rectok': lambda re: re * 5/4 + 273.15,
    'rector': lambda re: (re * 5/4 + 273.15) * 9/5
}

def pedir_datos_temperatura():
    valor = float(input("Introduce la temperatura: "))
    return valor

def mostrar_resultado_temperatura(temperatura):
    print(f"{temperatura}°C equivale a {diccionario_conversiones['ctof'](temperatura):.2f}°F")
    print(f"{temperatura}°C equivale a {diccionario_conversiones['ctok'](temperatura):.2f}K")
    print(f"{temperatura}°C equivale a {diccionario_conversiones['ctor'](temperatura):.2f}°R")
    print(f"{temperatura}°C equivale a {diccionario_conversiones['ctore'](temperatura):.2f}°Re")

    print(f"{temperatura}°F equivale a {diccionario_conversiones['ftoc'](temperatura):.2f}°C")
    print(f"{temperatura}°F equivale a {diccionario_conversiones['ftok'](temperatura):.2f}K")
    print(f"{temperatura}°F equivale a {diccionario_conversiones['ftor'](temperatura):.2f}°R")
    print(f"{temperatura}°F equivale a {diccionario_conversiones['ftore'](temperatura):.2f}°Re")

    print(f"{temperatura}K equivale a {diccionario_conversiones['ktoc'](temperatura):.2f}°C")
    print(f"{temperatura}K equivale a {diccionario_conversiones['ktof'](temperatura):.2f}°F")
    print(f"{temperatura}K equivale a {diccionario_conversiones['ktor'](temperatura):.2f}°R")
    print(f"{temperatura}K equivale a {diccionario_conversiones['ktore'](temperatura):.2f}°Re")

    print(f"{temperatura}°R equivale a {diccionario_conversiones['rtoc'](temperatura):.2f}°C")
    print(f"{temperatura}°R equivale a {diccionario_conversiones['rtof'](temperatura):.2f}°F")
    print(f"{temperatura}°R equivale a {diccionario_conversiones['rtok'](temperatura):.2f}K")
    print(f"{temperatura}°R equivale a {diccionario_conversiones['rtore'](temperatura):.2f}°Re")

    print(f"{temperatura}°Re equivale a {diccionario_conversiones['rectoc'](temperatura):.2f}°C")
    print(f"{temperatura}°Re equivale a {diccionario_conversiones['rectof'](temperatura):.2f}°F")
    print(f"{temperatura}°Re equivale a {diccionario_conversiones['rectok'](temperatura):.2f}K")
    print(f"{temperatura}°Re equivale a {diccionario_conversiones['rector'](temperatura):.2f}°Re")


def calcula_temperatura():
    temperatura = pedir_datos_temperatura()
    mostrar_resultado_temperatura(temperatura)


calcula_temperatura()
# Out:
# 100.0°C equivale a 212.00°F
# 100.0°C equivale a 373.15K
# 100.0°C equivale a 671.67°R
# 100.0°C equivale a 80.00°Re
# 100.0°F equivale a 37.78°C
# 100.0°F equivale a 310.93K
# 100.0°F equivale a 559.67°R
# 100.0°F equivale a 30.22°Re
# 100.0K equivale a -173.15°C
# 100.0K equivale a -279.67°F
# 100.0K equivale a 180.00°R
# 100.0K equivale a -138.52°Re
# 100.0°R equivale a -217.59°C
# 100.0°R equivale a -359.67°F
# 100.0°R equivale a 55.56K
# 100.0°R equivale a -174.08°Re
# 100.0°Re equivale a 125.00°C
# 100.0°Re equivale a 257.00°F
# 100.0°Re equivale a 398.15K
# 100.0°Re equivale a 716.67°Re

# %% [markdown]
# Nivell 1
# Exercici 3
# Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula.

# %%
import re # Importar modulo RE para tratar texto

def count_palabras(text):
    text = text.lower()  # Convierte mayusculas y minusculas
    texto_limpio = re.sub(r"[(),;.!¡?]", "", text) #limpiar texto por si hay caracteres raros
    palabras = texto_limpio.split() # split el texto en lista de palabras
    dicc_count = {} # Crear diccionario para guardar el count de palabras
    
    for cadapalabra in palabras:
        if cadapalabra in dicc_count:
            dicc_count[cadapalabra] += 1 # Si está en el dicc se añade aumenta en 1 el count
        else:
            dicc_count[cadapalabra] = 1 # Si no está en el dicc se añade y pone el count 1
    
    for cadapalabra, count in dicc_count.items():
        print(f"{cadapalabra}: {count}")

def pedir_datos_repeticion_palabras():
    text = input('haz un imput de un texto que te diré cuantas veces se repiten las palabras: ')
    return text

def funcio_principal_text():
    text = pedir_datos_repeticion_palabras()
    count_palabras(text)

funcio_principal_text()
# Out:
# hola: 2
# barbara: 1
# bon: 2
# dia: 1
# que: 1
# tal: 1
# estas: 1

# %% [markdown]
# Nivell 1
# - Exercici 4
# Diccionari invers.
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviats les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment.

# %%
dicionariconrep = {
    "key 1" : "valor 1",
    "key 2" : "valor 2",
    "key 3" : "valor 3",
    "key 4" : "valor 1",
    "key 5" : "valor 1"
}

reversedictionary = {}

def reversio_diccionari():
    for key, value in dicionariconrep.items():
        if value in reversedictionary:
            print(f"Valor '{value}' aparece más de una vez y por eso no se puede seguir invertiendo el diccionario. hicimos hasta aqui:")
            break
        reversedictionary[value] = key

def funcio_principal_reversedic():
    reversio_diccionari()
    print(reversedictionary)

funcio_principal_reversedic()
# Out:
# Valor 'valor 1' aparece más de una vez y por eso no se puede seguir invertiendo el diccionario. hicimos hasta aqui:
# {'valor 1': 'key 1', 'valor 2': 'key 2', 'valor 3': 'key 3'}

# %% [markdown]
# Nivell 2
# Exercici 1
# Diccionari invers amb duplicats
#
# Continuant amb l'exercici 4 del nivell 1: al client es va oblidar de comentar un detall i resulta que els valors en el diccionari original poden duplicar-se i més, per la qual cosa les claus intercanviades poden tenir duplicats. En aquest cas, en l'exercici anterior imprimies un missatge d'advertiment, ara, els valors del diccionari resultant hauran d'emmagatzemar-se com una llista. Tingues en compte que si és un valor únic no ha de ser una llista.

# %%
dicionariconrep = {
    "key 1" : "valor 1",
    "key 2" : "valor 2",
    "key 3" : "valor 3",
    "key 4" : "valor 1",
    "key 5" : "valor 1",
}

reversedictionaryvalueduplicat = {}

def reversio_diccionari_value_duplicat():
    for key, value in dicionariconrep.items():
        if value in reversedictionaryvalueduplicat: #si el valor ya existe, entra en la conversion a lista
            if not isinstance(reversedictionaryvalueduplicat[value], list): # si no es del tipo lista, entra para convertir en lista
                reversedictionaryvalueduplicat[value] = [reversedictionaryvalueduplicat[value]]  # [] hace con que se convierta en lista
            reversedictionaryvalueduplicat[value].append(key) # si ya existe y ya es lista no entra en el bucle anterior y solo append el valor
        else:
            reversedictionaryvalueduplicat[value] = key # si no existia antes, solo atribuye el valor, sin atribuir a lista

def funcio_principal_reversedic():
    reversio_diccionari_value_duplicat()
    print(reversedictionaryvalueduplicat)

funcio_principal_reversedic()
# Out:
# {'valor 1': ['key 1', 'key 4', 'key 5'], 'valor 2': 'key 2', 'valor 3': 'key 3'}

# %% [markdown]
# Nivell 2
# Exercici 2
# Conversió de tipus de dades
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir. Exemple de la llista que rep el client: [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]

# %%
# mirando en los elementos dentro de las listas presentes para la creacion de solo 2 otras listas
lista = [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']] #lista de ejemplo

#creacion de cada una de las listas. 
listafloat = [] #en esta entrarán los elementos que se pueden convertir en float
listanofloat = [] #en esta entrarán los elementos no convertibles a float.

def try_convert_float(val): #funcion que intenta convertir a float
    try: #funcao que tenta converter, se funciona retorna o valor em float perfeito
        return float(val)
    except (ValueError, TypeError): #se da algum error sea de value ou de type, retorna NONE
        return None

def process_item(item): #funcion de procesar el elemento
    if isinstance(item, (list, tuple)): #si es del tipo lista o tupla
        for subitem in item: #entrar en cada subitem de la lista o tupla
            process_item(subitem)  #pasa por la funcion otra vez pero ya con los elementos abiertos y no dentro de las tuplas/listas
    else:
        f = try_convert_float(item) #lleva a la funcion de intentar convertir en float
        print(f) #para ver que elementos que nao sao convertibles retornan "None" efectivamente
        if f is None:
            listanofloat.append(item) #append item en no float list
        else:
            listafloat.append(item) #append item en FLOAT list

def procesar_element():
    for x in lista: # para cada elemento dentro de la lista,
        process_item(x) #pasar por la funcion de procesar el elemento

def funcio_principal_flotants():
    procesar_element()
    print("Convertibles a float:", listafloat)
    print("No convertibles:", listanofloat)

funcio_principal_flotants()
# Out:
# 1.3
# None
# 10000000000.0
# None
# None
# 2.0
# 1.0
# 1.4
# None
# 1.0
# 2.0
# 3.0
# 3.4
# Convertibles a float: ['1.3', '1e10', '2', 1, 1.4, 1, 2, '3', '3.4']
# No convertibles: ['one', 'seven', '3-1/2', 'not-a-number']

# %% [markdown]
# Nivell 3
# Exercici 1
# Comptador i endreçador de paraules d'un text.
#
# El client va quedar content amb el comptador de paraules, però ara vol llegir arxius TXT i que calculi la freqüència de cada paraula ordenades dins de les entrades habituals del diccionari segons la lletra amb la qual comencen, és a dir, les claus han d'anar de la A a la Z i dins de la A hem d'anar de la A la Z. Per exemple, per a l'arxiu "tu_me_quieres_blanca.txt" la sortida esperada seria:

# %%
import re # Importar modulo RE (regular expresions) para tratar texto
from collections import defaultdict # Importar default dict para atualizacion automatica (para crear automaticamente un valor 0 cuando se crea key-valor)
from pprint import pprint  # Importar pretty print

# Importar archivo y meter el archivo en una variable y conferir si está bien, printando en tipo y el proprio contenido
with open("tu_me_quieres_blanca.txt", "r", encoding="utf-8") as archivo:
    contenido = archivo.read()
    print(contenido)
    print(type(contenido))

def limpiar_texto(contenido):
    #Limpiar la variable contenido usando en modulo RE de python que he importado que ayuda a hacer manipulaciones en textos
    texto_limpio = re.sub(r"[(),;.!¡]", "", contenido)     # quita signos. la R de raw string se utiliza para que los saltos de linea no se hagan pero si que se escriban \n literalmente, así se puede quitar luego
    texto_limpio = re.sub(r"\s+", " ", texto_limpio)       # reemplaza saltos, tabs y espacios (no solo saltos como seria con \n) múltiples (por eso el +) por 1 solo espacio 
    return texto_limpio

def split_into_list(texto_limpio):
    # crear una lista a partir del texto tractado, splitting cada palabra como un item
    return texto_limpio.split()

# crear el subdiccionario con conteo automático donde el valor atribuido es 0 si hay una nueva key
def crear_subdiccionario():
    return defaultdict(int)

def crear_diccionario_principal():
    # diccionario principal, que creará subdiccionarios automáticamente buscando el DEF. también se podria hacer con "lambda: defaultdict(int)"
    return defaultdict(crear_subdiccionario)

def atribuicion_letra_palabra_al_diccionario(diccionario, lista_palabras):
    # atribuicion al subdiccionario de LETRAS y actualizacion de valor de cada palabra
    for palabra in lista_palabras: #percorre la lista
        letra = palabra[0].lower() # pon en lowercase para comparar primera letra y atribui esta letra a la variable LETRA
        diccionario[letra][palabra] += 1 #accede el key LETRA y luego el key PALABRA y entonces al valor de PALABRA suma 1 al valor existente previamente
    return diccionario

def print_diccionario(diccionario):
    # pprint printa pretty para que se vea mejor
    pprint(diccionario)


def funcio_principal_diccionario_count(contenido):
    texto_limpio = limpiar_texto(contenido)
    lista_palabras = split_into_list(texto_limpio)
    diccionario = crear_diccionario_principal()
    diccionario = atribuicion_letra_palabra_al_diccionario(diccionario, lista_palabras)
    print_diccionario(diccionario)


funcio_principal_diccionario_count(contenido)
# Out:
# Tú me quieres alba,
# me quieres de espumas,
# me quieres de nácar.
# Que sea azucena
# Sobre todas, casta.
# De perfume tenue.
# Corola cerrada .
#
# Ni un rayo de luna
# filtrado me haya.
# Ni una margarita
# se diga mi hermana.
# Tú me quieres nívea,
# tú me quieres blanca,
# tú me quieres alba.
#
# Tú que hubiste todas
# las copas a mano,
# de frutos y mieles
# los labios morados.
# Tú que en el banquete
# cubierto de pámpanos
# dejaste las carnes
# festejando a Baco.
# Tú que en los jardines
# negros del Engaño
# vestido de rojo
# corriste al Estrago.
#
# Tú que el esqueleto
# conservas intacto
# no sé todavía
# por cuáles milagros,
# me pretendes blanca
# (Dios te lo perdone),
# me pretendes casta
# (Dios te lo perdone),
# ¡me pretendes alba!
#
# Huye hacia los bosques,
# vete a la montaña;
# límpiate la boca;
# vive en las cabañas;
# toca con las manos
# la tierra mojada;
# alimenta el cuerpo
# con raíz amarga;
# bebe de las rocas;
# duerme sobre escarcha;
# renueva tejidos
# ...
